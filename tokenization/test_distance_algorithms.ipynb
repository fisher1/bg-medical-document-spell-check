# %%
import pandas as pd

# %% [markdown]
# ### Load clean data and extract unigrams

# %%
df = pd.read_csv(
    'unigrams.csv', 
    keep_default_na=False,
    na_values=[
        '-1.#IND', '1.#QNAN', '1.#IND', '-1.#QNAN', '#N/A N/A', '#N/A', 'N/A', 'n/a', '', '#NA', 'NULL', 'null', 'NaN', '-NaN', 'nan', '-nan', ''
    ]
)

# %% [markdown]
# ## Test distance algorithms

# %% [markdown]
# ### Get top unigrams

# %%
unigrams = list(df[['Word', 'Count']].itertuples(index=False, name=None))
print('====Unigrams length====')
print(len(unigrams))
print('====First 30 unigrams====')
print(unigrams[0:30])

top_unigrams_count = round(len(unigrams) * 0.01)
print('====Top unigrams length====')
print(top_unigrams_count)
top_unigrams = unigrams[0:top_unigrams_count]
# Out:
# ====Unigrams length====
# 43291
# ====First 30 unigrams====
# [('и', 31679), ('на', 27252), ('без', 27204), ('б.о', 22399), ('RR', 22049), ('Корем', 17239), ('Cor', 16872), ('в', 16477), ('дишане', 14264), ('мек', 12803), ('РСД', 12270), ('с', 12264), ('тонове', 11832), ('се', 10480), ('отоци', 10069), ('не', 9817), ('дейност', 9076), ('ясни', 8517), ('Пулмо', 8514), ('мин', 8215), ('за', 8093), ('Крайници', 7748), ('везикуларно', 7612), ('сърдечна', 6929), ('хрипове', 6524), ('неболезнен', 6524), ('дроб', 6019), ('ритмична', 5503), ('по', 5476), ('статус', 5347)]
# ====Top unigrams length====
# 433

# %% [markdown]
# ### Jaccard distance

# %%
from nltk.metrics.distance import jaccard_distance

top_variants = []

for unigram, _ in top_unigrams:
    if len(unigram) < 3: continue
    variants = { unigram: [] }
    for other_unigram, _ in unigrams:
        distance = jaccard_distance(set(unigram), set(other_unigram))
        if distance < 0.25 and unigram != other_unigram:
            variants[unigram].append(other_unigram)
    top_variants.append(variants)

print('====First 30 unigram variants (Jaccard distance)====')
print(top_variants[0:30])
# Out:
# ====First 30 unigram variants (Jaccard distance)====
# [{'без': ['безз', 'безе', 'ебез']}, {'б.о': ['б.о.', 'б.оо', 'бб.о']}, {'Корем': ['Коремен', 'мм.Корем', 'м.Корем', 'орем', 'Кожрем', 'Кореммек', 'о.Корем', 'Кореим', 'Кореммеко', 'Корема', 'Коер', 'Корме', 'Коарем', 'Коремно', 'UКорем', 'Коремп', 'Коре']}, {'Cor': []}, {'дишане': ['дадени', 'вдишване', 'дишанес', 'дишанел', 'дишани', 'дешане', 'издишане', 'дишаен', 'дишене', 'дишан', 'диишане', 'диашне', 'дишне', 'днешна', 'дишване', 'дишени', 'ишане', 'дишишане', 'дишанне', 'диша-не', 'деишане', 'дишанеи', 'дишавне', 'дишание', 'иьдишане', 'дишане.', 'дишае', 'дишанеRR', 'дишанев', 'дишанееедри', 'дишанеез', 'дзишане', 'идишване', 'дишарне', 'шишане', 'дишанене', 'дишаяне', 'издишнане']}, {'мек': []}, {'РСД': ['РДС', 'СРД', 'ДРС']}, {'тонове': ['цветно', 'Цветно', 'тоновете', 'отново', 'неговото', 'тонове.', 'тоново', 'сетовност', 'нове', 'тоонве', 'тонов', 'онове', 'тонаве', 'тононве', 'товнове', 'оцветено', 'новото', 'тоонове', 'тоное', 'фтонове', 'тонве', 'тгонове', 'евент', 'ттонове', 'тоновете.', 'тнове', 'таонаве', 'тоновет', 'тоннове', 'вовено', 'тоинове', 'тоне', 'тоновеи', 'тоновве', 'тонвое', 'неот', 'оцветен', 'тонтове', 'тооннове']}, {'отоци': ['оттоци', 'Отоци', 'отриц', 'отоципо', 'отци', 'отоци.', 'тоци', 'зотоци', 'Oтоци', 'Оттоци', 'отноци', 'лицито', 'атоци', 'отозци', 'отнтоци', 'зотоиц', 'отоиц', 'оитоци', 'отооци', 'хоттоци', 'ототци', 'сотоци', 'отoци']}, {'дейност': ['дейнос', 'с.дейност', 'деност', 'сърдейност', 'дейностясни', 'дейности', 'дейост', 'дейност.', 'дейнот', 'р.с.дейност', 'дейносст', 'дейноскт', 'сърддейност', 'недост', 'десното', 'деййност', 'дейнст', 'дейножст', 'деайност', 'дейниост', 'дейностс', 'дейност.Щ', 'десност', 'дейнсот', 'дейностq', 'дейностг', 'дейносттон', 'дейностчисти', 'дейностчести', 'ърдейност', 'съдейност', 'сдърдейност', 'сденост', 'съддейност', 'сэд.дейност', 'съд.дейност', 'пдейност', 'денйност']}, {'ясни': ['неясни', 'сясни', 'иясни', 'дясния', 'мясни', 'ясин', 'дясни', 'ястни', 'минясни', 'Бясни', 'яснии', 'ниския', 'тясни', 'яснеи', 'яснои', 'яскни', 'синя', 'яясни']}, {'Пулмо': ['м.Пулмо', 'Пулм', 'улмо', 'Пулмои', 'о.Пулмо', 'Пуло', 'мм.Пулмо', 'Пумо', 'ПШулмо', 'Пуклмо', 'Пуллмо', 'Пулмоо', 'Плмо', 'Пулвмо']}, {'мин': ['миним', 'мини', 'мни']}, {'Крайници': ['Краиници', 'Крайничци', 'мин.Крайници', 'л.Крайници', 'Крайнициш', 'Краници', 'Крайнци', 'Крайни', 'Крайниците', 'Крйници', 'Крайнициб', 'Крайниц', 'мм.Крайници', 'о.Крайници', 'Крайнеици', 'нор.Крайници', 'Кранйици', 'Ккрайници', 'Карйници', 'Кайници', 'Краайници', 'КО.Крайници', 'Краиниц', 'О.Крайници', 'райници', 'р.д.Крайници', 'ДАКрайници', 'Крайненици', 'Крайнници', 'Крайнишци', 'Краийници', 'Крайницис', 'Крайниции', 'син.Крайници']}, {'везикуларно': ['Везикуларно', 'везиколарно', 'везикулярно', 'ДС-везикуларно', 'дишане-везикуларно', 'визикуларно', 'везиуларно', 'резервоари-контролира', 'везикулозно', 'дробове-везикуларно', 'отсл.везикуларно', 'о.Везикуларно', 'варикозен', 'везикулaрно', 'везекуларно', 'везикулозен', 'Дишане-везикуларно', 'везикурапно', 'везикуларна', 'везикларно', 'везикурарно', 'ма-везикуларно', 'везикулрно', 'везикуларн', 'везикуларнор', 'чистовезикуларно', 'везкуларно', 'везикуларнодишане', 'езикуларно', 'везикуларни', 'тонове.Везикуларно', 'везинуларно', 'везикуларен', 'взикуларно', 'пулно-везикуларно', 'нормовезикуларно', 'нормовезикуларноо', 'изостреновезикуларно', 'везикулатно', 'контрол-на-таз-резевоари', 'везикуларноя', 'веикуларно', 'везикулано', 'везикулар', 'везикулорно', 'др-везикуларно', 'визшкулаорно', 'везикуларноq', 'везиукларно', 'везикулерно', 'везикално', 'изостренопвезикуларно', 'везикулар-но', 'Д.С.везикуларно', 'макулопапулозновезикуларен', 'везикулавно', 'тон.везикуларно', 'везиккуларно', 'везикуларво', 'везикуларено', 'викуларно', 'доробове-везикуларно', 'бронховезикуларно', 'вевикуларно', 'рана.Везикуларно', 'свезикуларно', 'гр.вез.везикуларно', 'везикулозни', 'Д.с.везикуларно', 'Изостреновезикуларно', 'ДСІвезикуларно', 'везикурларно', 'Дс-везикуларно',  ...

# %% [markdown]
# ### Edit (Levenshtein) distance

# %%
from nltk.metrics.distance import edit_distance

top_variants = []

for unigram, _ in top_unigrams:
    if len(unigram) < 3: continue
    variants = { unigram: [] }
    for other_unigram, _ in unigrams:
        distance = jaccard_distance(set(unigram), set(other_unigram))
        if distance > 0.35: continue
        distance = edit_distance(unigram, other_unigram)
        if distance < 3 and unigram != other_unigram:
            variants[unigram].append(other_unigram)
    top_variants.append(variants)

print('====First 30 unigram variants (Edit (Levenshtein) distance)====')
print(top_variants[0:30])
# Out:
# ====First 30 unigram variants (Edit (Levenshtein) distance)====
# [{'без': ['бе', 'ез', 'белз', 'зе', 'бз', 'б.ез', 'Сбез', 'обез', 'беиз', 'безп', 'сбез', 'Лбез', 'бмез', 'безь', 'безз', 'безе', 'Дбез', 'бедз', 'бжез', 'убез', 'ебез', 'буез', 'пбез']}, {'б.о': ['б.', 'о.', 'б.о.', 'бо', 'боб', 'б.ол', 'б.б', 'б.о-', 'об.г', 'б.оо', 'б.ло', 'бб.о']}, {'Корем': ['корем', 'Коремен', 'Коремни', 'м.Корем', 'орем', 'Кожрем', 'Коремна', 'Кореm', 'Kорем', 'Кохер', 'о.Корем', 'Корен', 'О.Корем', 'Кореим', 'Кореб', 'd.Корем', 'Карем', 'Коремът', 'Корема', 'Корев', 'Коер', 'д.Корем', 'горем', 'Корме', 'Коарем', 'СДКорем', 'Коремно', 'UКорем', 'Коремп', 'Корeм', 'С.Корем', 'Коре']}, {'Cor': ['ЛCor', 'Corр', 'or', 'Cor-']}, {'дишане': ['Дишане', 'дишането', 'вдишване', 'дищане', 'дишания', 'дишанес', 'дишанел', 'дишани', 'дишанe', 'дешане', 'диша', 'издишане', 'дишаен', 'дишене', 'дишан', 'диишане', 'дошане', 'сишане', 'шане', 'вишане', 'дипане', 'диашне', 'дишне', 'дихане', 'дишване', 'дишени', 'ишане', 'дишишане', 'вдиване', 'дишанне', 'диша-не', 'дишоне', 'здишване', 'дишаnе', 'деишане', 'дишанеи', 'дишавне', 'дишание', 'иьдишане', 'дишане.', 'дижане', 'дишане-в', 'дишае', 'дишанеRR', 'дишаме', 'душане', 'дишанев', 'дишанеез', 'дзишане', 'идишване', 'дишарне', 'шишане', 'дишанене', 'дишаяне', 'дишаве', 'дишане-с', 'в.дишане']}, {'мек': ['меки', 'меко', 'мека', 'ме', 'мекб', 'меку', 'ем', 'ек', 'мекр', 'мчек']}, {'РСД': ['Р.С.Д', 'ДС', 'СД', 'СР', 'РНСД', 'РС', 'РД', 'СРС', 'РДС', 'ССР', 'СРД', 'ССД', 'РТСД', 'РУСД', 'Р.СД', 'ДРД', 'РБСД', 'РСС', 'РСНД', 'РДР', 'ДРС']}, {'тонове': ['Тонове', 'тоновете', 'с.тонове', 'тонове.', 'тоново', 'тонови', 'нове', 'тоновe', 'тоонве', 'тонов', 'онове', 'тонаве', 'тононве', 'товнове', 'гонове', 'тоонове', 'тоное', 'фтонове', 'тонве', 'тгонове', 'ттонове', 'тнове', 'станове', 'таонаве', 'тоновет', 'тоннове', 'тонувез', 'тоинове', 'тонову', 'тоне', 'тоновеи', 'тон.в', 'тоновве', 'тонвое', 'тономе', 'тонтове', 'тооннове']}, {'отоци': ['оттоци', 'Отоци', 'отоципо', 'отци', 'отоц', 'отоци.', 'тоци', 'зотоци', 'отоци-с', 'Oтоци', 'отоцо', 'Оттоци', 'отноци', 'о.Отоци', 'итици', 'атоци', 'отозци', 'беотоци', 'отнтоци', 'отоиц', 'оитоци', 'отооци', 'хоттоци', 'ооци', 'ототци', 'отои', 'сотоци', 'отoци']}, {'дейност': ['деиност', 'Дейност', 'десностр', 'дейнос', 'деинност', 'дийност', 'с.дейност', 'деност', 'дейносш', 'дейности', 'дейост', 'деаност', 'дейност.', 'дейнот', 'дeйност', 'дейнаст', 'дейносст', 'дейноскт', 'деъност', 'деййност', 'дейнст', 'дейножст', 'деайност', 'дейниост', 'дейностс', 'дейност.Щ', 'десност', 'дейнсот', 'дейностq', 'дейностг', 'дейнокт', 'деймост', 'ърдейност', 'съдейност', 'съейност', 'сденост', 'пдейност', 'денйност', 'деиностс']}, {'ясни': ['поясни', 'неясни', 'сясни', 'иясни', 'яснифр', 'дясния', 'мясни', 'ясин', 'сини', 'дясни', 'ястни', 'Бясни', 'яси', 'яснии', 'ясни.А', 'тясни', 'р.ясни', 'сни', 'д.ясни', 'яснеи', 'яснои', 'яскни', 'СДясни', 'яясни']}, {'Пулмо': ['пулмо', 'Рулмо', 'Пелмо', 'м.Пулмо', 'а.Пулмо', 'Пулм', 'Пулма', 'улмо', 'рулмо', 'Пулмои', 'о.Пулмо', 'Пуло', 'С.Пулмо', 'Пурмо', 'г.Пулмо', 'Пилмо', 'е.Пулмо', 'А.Пулмо', 'Пумо', 'Пуимо', 'ПШулмо', 'Пуклмо', 'О.Пулмо', 'Пулно', 'Пумно', 'Д.Пулмо', 'Пулмоед', 'Пуллмо', 'Пулво', 'Пулмоо', 'Плмо', 'Пулвмо', 'ПУлмо']}, {'мин': ['умин', 'им', 'мн', 'ми', 'миним', 'мин.', 'ин', 'ни', 'мини', 'дмин', 'Імин', 'мин-', 'мени', 'мни']}, {'Крайници': ['крайници', 'Краиници', 'Крайничци', 'Kрайници', 'л.Крайници', 'Крайнициш', 'Краници', 'Крайнци', 'Крайни', 'Крайнизи', 'Крайниците', 'Крйници', 'Крайнициб', 'Крайниц', 'о.Крайници', 'крайниц', 'Крайнеици', 'Кранйици', 'Крайнич', 'Крайничи', 'срайници', 'Кройници', 'Ккрайници', 'Карйници', 'ккрайници', 'Кайници', 'Щрайници', 'Краайници', 'Краиниц', 'О.Крайници', 'крайници.', 'икрайници', 'райници', 'крайница', 'ДАКрайници', 'Крайненици', 'крайнци', 'краяйници', 'краойници', 'Крайнници', 'крайнициб', 'Крайнишци', 'красйници', 'Краийници', 'Крайницис', 'крайнице', 'Крайниции', 'крайиници', 'крайъници']}, {'везикуларно': ['Везикуларно', 'везико ...

# %% [markdown]
# ### Masi distance

# %%
from nltk.metrics.distance import masi_distance

top_variants = []

for unigram, _ in top_unigrams:
    if len(unigram) < 3: continue
    variants = { unigram: [] }
    for other_unigram, _ in unigrams:
        # distance = jaccard_distance(set(unigram), set(other_unigram))
        # if distance > 0.35: continue
        distance = masi_distance(set(unigram), set(other_unigram))
        if distance < 0.35 and unigram != other_unigram:
            variants[unigram].append(other_unigram)
    top_variants.append(variants)

print('====First 30 unigram variants (MASI distance)====')
print(top_variants[0:30])
# Out:
# ====First 30 unigram variants (MASI distance)====
# [{'без': ['безз', 'безе', 'ебез']}, {'б.о': ['б.о.', 'б.оо', 'бб.о']}, {'Корем': ['Корме']}, {'Cor': []}, {'дишане': ['дишаен', 'диишане', 'диашне', 'дишишане', 'дишанне', 'деишане', 'дишанеи', 'дишание', 'дишанене']}, {'мек': []}, {'РСД': ['РДС', 'СРД', 'ДРС']}, {'тонове': ['тоновете', 'тоонве', 'тононве', 'товнове', 'тоонове', 'тонве', 'ттонове', 'тнове', 'тоновет', 'тоннове', 'тоновве', 'тонвое', 'тонтове', 'тооннове']}, {'отоци': ['оттоци', 'отци', 'тоци', 'отоиц', 'оитоци', 'отооци', 'ототци']}, {'дейност': ['дейносст', 'деййност', 'дейностс', 'дейнсот', 'дейносттон', 'денйност']}, {'ясни': ['сясни', 'иясни', 'ясин', 'яснии', 'синя', 'яясни']}, {'Пулмо': ['Пуллмо', 'Пулмоо']}, {'мин': ['миним', 'мини', 'мни']}, {'Крайници': ['Крайнци', 'Крайниц', 'Кранйици', 'Карйници', 'Краайници', 'Крайнници', 'Краийници', 'Крайниции']}, {'везикуларно': ['везикуларнор', 'везиукларно', 'везиккуларно', 'везикуларено', 'везикурларно', 'везикуларнно', 'везикурално', 'везикуларано', 'везикуларнао']}, {'сърдечна': ['сърдечан', 'нсърдечна', 'сръдечна', 'дсърдечна']}, {'хрипове': ['хриповев', 'хирпове', 'хрпипове', 'хриповер', 'хрпиове', 'хриппове', 'ихрипове', 'хриипове', 'хрипоев', 'хрипиове', 'хриепове', 'хриповехрипове', 'хриповее']}, {'неболезнен': ['болезнен', 'болезнено', 'болезн', 'неболезнено', 'безболезнен', 'болезнене', 'неболезен', 'неболезн', 'болезне', 'болезен', 'неболезнене', 'неболез', 'неболзнен', 'неболезне', 'неболзнено', 'неболезненен', 'неболезенен', 'неболезнне', 'неболезннен', 'болезннен', 'болзенен', 'болезнео', 'оболезнен', 'болезене', 'болезенен', 'неболезненн', 'небелознен', 'неболезненно', 'небелезнено', 'болезненен', 'болезненн', 'болезнне', 'болеззнен', 'безболезн', 'болезненл', 'болезннене', 'боллезнен', 'необолезнен', 'болезенн', 'болеезнен', 'болзнен']}, {'дроб': ['добро', 'дрбо', 'ддроб', 'дбро']}, {'ритмична': ['аритмична', 'риттмична', 'ритмимчна', 'аритмичан', 'ртмична', 'ритимчина', 'ритимична', 'ритмчина', 'ритмичан', 'артмична', 'ритмчна']}, {'статус': ['сатус', 'устата', 'статуса', 'уста', 'стаус', 'статсу', 'саттус', 'сттатус', 'статусстатус', 'стату', 'сатсу', 'устатата']}, {'общо': ['общ', 'бщо', 'ообщо', 'бощо', 'обощо', 'обощ']}, {'двустранно': ['двустрано', 'двустраннно', 'двустарнно', 'двустранноо', 'двустранносу', 'отрдвустранно', 'двустрнанно', 'двудстранно', 'дувстарно', 'двустранвно', 'двустарно', 'вдустранно', 'двусвтранно', 'двустронна']}, {'ССС': ['С', 'СС']}, {'състояние': ['състоянието', 'сътояние', 'съсотяние', 'съсътояние', 'сътоянието', 'състтояние', 'състиояниее', 'състояниеие', 'състояниеи', 'съсотянние', 'състоянояние', 'съсстояние', 'състоянние', 'състоняие', 'състояниие', 'съътояние', 'ссътояние', 'състояниее', 'сътсояние', 'състояяние', 'състояниео', 'състотояние']}, {'палпират': ['палират', 'палпирта', 'алпират', 'палпирт', 'палпирата', 'палпираат', 'палипрат', 'ппалпират', 'палпирлат', 'палппират']}, {'слезка': ['слезска', 'слезак']}, {'вез': ['зев', 'взе', 'звез']}, {'крайници': ['крайниц', 'крайнииц', 'ккрайници', 'икрайници', 'крайницици', 'крайница', 'крайнци', 'крайницини', 'карйниц', 'накрайници', 'крайиници']}, {'чисто': ['ичисто', 'чисот', 'чистоо', 'чиссто']}]
